# %% [markdown]
# # 드라이브 마운트

# %%
from google.colab import drive
drive.mount('/drive')
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %% [markdown]
# # 깃허브 연결

# %%
cd /drive/MyDrive/Colab Notebooks
# Out:
# /drive/MyDrive/Colab Notebooks

# %%
# !git clone https://happygeon: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@github.com/happygeon/ML.git
# Out:
# Cloning into 'ML'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 11 (delta 1), reused 9 (delta 1), pack-reused 0
# Unpacking objects: 100% (11/11), done.

# %%
# !git config --global user.email 'happygeon02@yonsei.ac.kr'

# %%
# !git config --global user.name 'happygeon'

# %% [markdown]
# # 깃허브 푸쉬

# %%
cd /drive/MyDrive/Colab Notebooks
# Out:
# /drive/MyDrive/Colab Notebooks

# %%
# !git add .

# %%
# !git commit -m "-"
# Out:
# [main 0707fcb] -
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite ML_study.ipynb (92%)

# %%
# !git push
# Out:
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://happygeon: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@github.com/happygeon/ML.git/'
