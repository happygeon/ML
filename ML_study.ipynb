# %% [markdown]
# # 드라이브 마운트

# %%
from google.colab import drive
drive.mount('/drive')
# Out:
# Mounted at /drive

# %% [markdown]
# # 깃허브 연결

# %%
cd /drive/MyDrive/Colab Notebooks
# Out:
# /drive/MyDrive/Colab Notebooks

# %%
# !git clone https://happygeon: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@github.com/happygeon/ML.git
# Out:
# Cloning into 'ML'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 6 (delta 0), reused 4 (delta 0), pack-reused 0
# Unpacking objects: 100% (6/6), done.

# %%
# !git config --global user.email 'happygeon02@yonsei.ac.kr'

# %%
# !git config --global user.name 'happygeon'

# %% [markdown]
# # 깃허브 푸쉬

# %%
cd /drive/MyDrive/ML/Colab Notebooks
# Out:
# /drive/MyDrive/ML

# %%
# !git add .

# %%
# !git commit -m "-"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git push
# Out:
# Everything up-to-date

# %% [markdown]
# # 1.Basic

# %%
cd /drive/MyDrive/ML/1BASIC
# Out:
# /drive/MyDrive/ML/1BASIC

# %%
run test.py
# Out:
# 1
